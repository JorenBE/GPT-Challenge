# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
import matplotlib.pyplot as plt
from datetime import datetime
import ast

from gptchem_llama.analyze import OutPickle, OutFolder, add_traditional_ml
import gptchem_llama.plotting

from gptchem_llama.plotting import *

FOLDER_LLAMA = 'LearningCurve_models/out_llama'
FOLDER_GPTJ = 'LearningCurve_models/out'
FOLDER_MISTRAL = 'LearningCurve_models/out_mistral'

# %%
print('Llama')
try:
    folder_llma = OutFolder(FOLDER_LLAMA)
    folder_llma_df = folder_llma.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_llma_df.round(2))
except:
    print('Data not present')
# Out:
# Llama
#                                                       accuracy       f1_macro  \
#                                                           mean   sem     mean
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10             0.00  0.00     0.00
#                                            50             0.50  0.00     0.33
#                                            100            0.50  0.00     0.33
#                                            500            0.53  0.02     0.40
#                                            1000           0.63  0.05     0.57
#        20       Smiles         deltaG4_bin 10             0.00  0.00     0.00
#                                            50             0.59  0.09     0.48
#                                            100            0.57  0.07     0.46
#                                            500            0.63  0.07     0.57
#                                            1000           0.71  0.05     0.68
#
#                                                             f1_micro        \
#                                                         sem     mean   sem
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10          0.00     0.00  0.00
#                                            50          0.00     0.50  0.00
#                                            100         0.00     0.50  0.00
#                                            500         0.05     0.53  0.02
#                                            1000        0.07     0.63  0.05
#        20       Smiles         deltaG4_bin 10          0.00     0.00  0.00
#                                            50          0.15     0.59  0.09
#                                            100         0.12     0.57  0.07
#                                            500         0.12     0.63  0.07
#                                            1000        0.06     0.71  0.05
#
#                                                       kappa         lr       \
#                                                        mean   sem mean  sem
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10          0.00  0.00  0.0  0.0
#                                            50          0.00  0.00  0.0  0.0
#                                            100         0.00  0.00  0.0  0.0
#                                            500         0.07  0.05  0.0  0.0
#                                            1000        0.27  0.09  0.0  0.0
#        20       Smiles         deltaG4_bin 10          0.00  0.00  0.0  0.0
#                                            50          0.19  0.19  0.0  0.0
#                                            100         0.15  0.15  0.0  0.0
#                                            500         0.27  0.14  0.0  0.0
#                                            1000        0.43  0.09  0.0  0.0
#
#                                                       test_size
#                                                            mean  sem
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10              50.0  0.0
#                                            50              50.0  0.0
#                                            100             50.0  0.0
#                                            500             50.0  0.0
#                                            1000            50.0  0.0
#        20       Smiles         deltaG4_bin 10              50.0  0.0
#                                            50              50.0  0.0
#                                            100             50.0  0.0
#                                            500             50.0  0.0
#                                            1000            50.0  0.0

# %%
print('Mistral')
try:
    folder_mistral = OutFolder(FOLDER_MISTRAL)
    folder_mistral_df = folder_mistral.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_mistral_df)
except:
    print('Data not present')
# Out:
# Mistral
#                                                        accuracy            \
#                                                            mean       sem
# n_bins n_epochs representation target      train_size
# 2      20       Smiles         deltaG4_bin 10          0.160000  0.111355
#                                            50          0.660000  0.160000
#                                            100         0.573333  0.073333
#                                            500         0.546667  0.029059
#                                            1000        0.793333  0.037118
#
#                                                        f1_macro            \
#                                                            mean       sem
# n_bins n_epochs representation target      train_size
# 2      20       Smiles         deltaG4_bin 10          0.108280  0.057312
#                                            50          0.548886  0.215553
#                                            100         0.459770  0.126437
#                                            500         0.424561  0.055132
#                                            1000        0.784218  0.041151
#
#                                                        f1_micro            \
#                                                            mean       sem
# n_bins n_epochs representation target      train_size
# 2      20       Smiles         deltaG4_bin 10          0.160000  0.111355
#                                            50          0.660000  0.160000
#                                            100         0.573333  0.073333
#                                            500         0.546667  0.029059
#                                            1000        0.793333  0.037118
#
#                                                           kappa            \
#                                                            mean       sem
# n_bins n_epochs representation target      train_size
# 2      20       Smiles         deltaG4_bin 10          0.028243  0.023375
#                                            50          0.320000  0.320000
#                                            100         0.146667  0.146667
#                                            500         0.093333  0.058119
#                                            1000        0.586667  0.074237
#
#                                                            lr      test_size  \
#                                                          mean  sem      mean
# n_bins n_epochs representation target      train_size
# 2      20       Smiles         deltaG4_bin 10          0.0003  0.0      50.0
#                                            50          0.0003  0.0      50.0
#                                            100         0.0003  0.0      50.0
#                                            500         0.0003  0.0      50.0
#                                            1000        0.0003  0.0      50.0
#
#
#                                                        sem
# n_bins n_epochs representation target      train_size
# 2      20       Smiles         deltaG4_bin 10          0.0
#                                            50          0.0
#                                            100         0.0
#                                            500         0.0
#                                            1000        0.0

# %%
print('GPTJ')
try:
    folder_gptj = OutFolder(FOLDER_GPTJ)
    folder_gptj_df = folder_gptj.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_gptj_df)
except:
    print('Data not present')
# Out:
# GPTJ
#                                                        accuracy            \
#                                                            mean       sem
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10          0.000000  0.000000
#                                            50          0.686667  0.127192
#                                            100         0.846667  0.017638
#                                            500         0.873333  0.017638
#                                            1000        0.900000  0.023094
#        20       Smiles         deltaG4_bin 10          0.000000  0.000000
#                                            50          0.813333  0.076884
#                                            100         0.873333  0.040552
#                                            500         0.886667  0.037118
#                                            1000        0.880000  0.030551
#
#                                                        f1_macro            \
#                                                            mean       sem
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10          0.000000  0.000000
#                                            50          0.615520  0.163610
#                                            100         0.845717  0.017874
#                                            500         0.873062  0.017581
#                                            1000        0.899639  0.023177
#        20       Smiles         deltaG4_bin 10          0.000000  0.000000
#                                            50          0.798335  0.091567
#                                            100         0.871510  0.042129
#                                            500         0.886304  0.037342
#                                            1000        0.879727  0.030731
#
#                                                        f1_micro            \
#                                                            mean       sem
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10          0.000000  0.000000
#                                            50          0.686667  0.127192
#                                            100         0.846667  0.017638
#                                            500         0.873333  0.017638
#                                            1000        0.900000  0.023094
#        20       Smiles         deltaG4_bin 10          0.000000  0.000000
#                                            50          0.813333  0.076884
#                                            100         0.873333  0.040552
#                                            500         0.886667  0.037118
#                                            1000        0.880000  0.030551
#
#                                                           kappa            \
#                                                            mean       sem
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10          0.000000  0.000000
#                                            50          0.373333  0.254384
#                                            100         0.693333  0.035277
#                                            500         0.746667  0.035277
#                                            1000        0.800000  0.046188
#        20       Smiles         deltaG4_bin 10          0.000000  0.000000
#                                            50          0.626667  0.153768
#                                            100         0.746667  0.081104
#                                            500         0.773333  0.074237
#                                            1000        0.760000  0.061101
#
#                                                            lr      test_size  \
#                                                          mean  sem      mean
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10          0.0003  0.0      50.0
#                                            50          0.0003  0.0      50.0
#                                            100         0.0003  0.0      50.0
#                                            500         0.0003  0.0      50.0
#                                            1000        0.0003  0.0      50.0
#        20       Smiles         deltaG4_bin 10          0.0003  0.0      50.0
#                                            50          0.0003  0.0      50.0
#                                            100         0.0003  0.0      50.0
#                                            500         0.0003  0.0      50.0
#                                            1000        0.0003  0.0      50.0
#
#
#                                                        sem
# n_bins n_epochs representation target      train_size
# 2      15       Smiles         deltaG4_bin 10          0.0
#                                            50          0.0
#                                            100         0.0
#                                            500         0.0
#                                            1000        0.0
#        20       Smiles         deltaG4_bin 10          0.0
#                                            50          0.0
#                                            100         0.0
#                                            500         0.0
#                                            1000        0.0

# %%
def plot():
    fig, ax = plt.subplots(4,1, figsize=(ONE_COL_WIDTH_INCH, TWO_COL_GOLDEN_RATIO_HEIGHT_INCH),constrained_layout = True , sharex=True)
    try:
        folder_llma.plot_analysis(bins = 2, representation='Smiles', target = 'deltaG4_bin', ax = ax, exclude = {'n_epochs': [15]})
        folder_gptj.plot_analysis(bins = 2, representation='Smiles', target = 'deltaG4_bin', ax = ax, exclude = {'n_epochs': [15]})
        folder_mistral.plot_analysis(bins = 2, representation='Smiles', target = 'deltaG4_bin', ax = ax, exclude = {'n_epochs': [15]})

        folder_mistral.add_zero_rule(ax = ax, color = 'slategray', exclude = {'train_size': [5]})
    except Exception as e:
        print('No data yet',e)
    #ax = add_traditional_ml(ax, file = './ml/ActivationEnergy_cycloadditions_traditional_ml.csv', target='E_bin')
    #ax = add_zero_rule(ax)

    import matplotx
    matplotx.line_labels(ax[0])

    ax[3].tick_params(axis='x', rotation=45)

    fig.savefig('FreeEnergy_LearningCurves_allModels.pdf')

plot()

# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
import matplotlib.pyplot as plt
from datetime import datetime
import ast

from gptchem_llama.analyze import OutPickle, OutFolder, add_traditional_ml
import gptchem_llama.plotting

from gptchem_llama.plotting import *

FOLDER_LLAMA = 'LearningCurves_models/out_llama'
FOLDER_GPTJ = 'LearningCurves_models/out_gptj'
FOLDER_MISTRAL = 'LearningCurves_models/out_mistral'

# %%
print('Llama')
try:
    folder_llma = OutFolder(FOLDER_LLAMA)
    folder_llma_df = folder_llma.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_llma_df.round(2))
except:
    print('Data not present')
# Out:
# Llama
#                                                    accuracy       f1_macro  \
#                                                        mean   sem     mean
# n_bins n_epochs representation target   train_size
# 2      25       elemetns_all   HER_bool 50             0.64  0.06     0.63
#                                OER_bool 50             0.83  0.10     0.82
#                                VIS_bool 50             0.83  0.05     0.83
#
#                                                          f1_micro       kappa  \
#                                                      sem     mean   sem  mean
# n_bins n_epochs representation target   train_size
# 2      25       elemetns_all   HER_bool 50          0.05     0.64  0.06  0.28
#                                OER_bool 50          0.11     0.83  0.10  0.67
#                                VIS_bool 50          0.05     0.83  0.05  0.67
#
#                                                            lr      test_size  \
#                                                      sem mean  sem      mean
# n_bins n_epochs representation target   train_size
# 2      25       elemetns_all   HER_bool 50          0.11  0.0  0.0      12.0
#                                OER_bool 50          0.19  0.0  0.0       6.0
#                                VIS_bool 50          0.10  0.0  0.0      14.0
#
#
#                                                     sem
# n_bins n_epochs representation target   train_size
# 2      25       elemetns_all   HER_bool 50          0.0
#                                OER_bool 50          0.0
#                                VIS_bool 50          0.0

# %%
print('Mistral')
try:
    folder_mistral = OutFolder(FOLDER_MISTRAL)
    folder_mistral_df = folder_mistral.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_mistral_df.round(2))
except:
    print('Data not present')
# Out:
# Mistral
#                                                    accuracy       f1_macro  \
#                                                        mean   sem     mean
# n_bins n_epochs representation target   train_size
# 2      25       elemetns_all   HER_bool 50             0.89  0.03     0.89
#                                OER_bool 50             0.78  0.15     0.77
#                                VIS_bool 50             0.95  0.05     0.95
#
#                                                          f1_micro       kappa  \
#                                                      sem     mean   sem  mean
# n_bins n_epochs representation target   train_size
# 2      25       elemetns_all   HER_bool 50          0.03     0.89  0.03  0.78
#                                OER_bool 50          0.15     0.78  0.15  0.56
#                                VIS_bool 50          0.05     0.95  0.05  0.90
#
#                                                            lr      test_size  \
#                                                      sem mean  sem      mean
# n_bins n_epochs representation target   train_size
# 2      25       elemetns_all   HER_bool 50          0.06  0.0  0.0      12.0
#                                OER_bool 50          0.29  0.0  0.0       6.0
#                                VIS_bool 50          0.10  0.0  0.0      14.0
#
#
#                                                     sem
# n_bins n_epochs representation target   train_size
# 2      25       elemetns_all   HER_bool 50          0.0
#                                OER_bool 50          0.0
#                                VIS_bool 50          0.0

# %%
print('GPTJ')
try:
    folder_gptj = OutFolder(FOLDER_GPTJ)
    folder_gptj_df = folder_gptj.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_gptj_df)
except:
    print('Data not present')
# Out:
# GPTJ
#                                                       accuracy            \
#                                                           mean       sem
# n_bins n_epochs representation   target   train_size
# 2      25       elements_linkers HER_bool 50          0.861111  0.055556
#                                  OER_bool 50          0.722222  0.111111
#                                  VIS_bool 50          0.880952  0.023810
#                 elements_nodes   HER_bool 50          0.722222  0.027778
#                                  OER_bool 50          0.944444  0.055556
#                                  VIS_bool 50          0.690476  0.047619
#                 elemetns_all     HER_bool 50          0.916667  0.048113
#                                  OER_bool 50          0.944444  0.055556
#                                  VIS_bool 50          0.857143  0.041239
#                 mofkey           HER_bool 50          0.916667  0.000000
#                                  OER_bool 50          0.888889  0.111111
#                                  VIS_bool 50          0.880952  0.047619
#
#                                                       f1_macro            \
#                                                           mean       sem
# n_bins n_epochs representation   target   train_size
# 2      25       elements_linkers HER_bool 50          0.855167  0.060917
#                                  OER_bool 50          0.714286  0.114286
#                                  VIS_bool 50          0.878846  0.024679
#                 elements_nodes   HER_bool 50          0.702195  0.038837
#                                  OER_bool 50          0.942857  0.057143
#                                  VIS_bool 50          0.683770  0.050617
#                 elemetns_all     HER_bool 50          0.916472  0.048113
#                                  OER_bool 50          0.942857  0.057143
#                                  VIS_bool 50          0.853583  0.044147
#                 mofkey           HER_bool 50          0.916084  0.000000
#                                  OER_bool 50          0.888889  0.111111
#                                  VIS_bool 50          0.877270  0.050935
#
#                                                       f1_micro            \
#                                                           mean       sem
# n_bins n_epochs representation   target   train_size
# 2      25       elements_linkers HER_bool 50          0.861111  0.055556
#                                  OER_bool 50          0.722222  0.111111
#                                  VIS_bool 50          0.880952  0.023810
#                 elements_nodes   HER_bool 50          0.722222  0.027778
#                                  OER_bool 50          0.944444  0.055556
#                                  VIS_bool 50          0.690476  0.047619
#                 elemetns_all     HER_bool 50          0.916667  0.048113
#                                  OER_bool 50          0.944444  0.055556
#                                  VIS_bool 50          0.857143  0.041239
#                 mofkey           HER_bool 50          0.916667  0.000000
#                                  OER_bool 50          0.888889  0.111111
#                                  VIS_bool 50          0.880952  0.047619
#
#                                                          kappa            \
#                                                           mean       sem
# n_bins n_epochs representation   target   train_size
# 2      25       elements_linkers HER_bool 50          0.722222  0.111111
#                                  OER_bool 50          0.444444  0.222222
#                                  VIS_bool 50          0.761905  0.047619
#                 elements_nodes   HER_bool 50          0.444444  0.055556
#                                  OER_bool 50          0.888889  0.111111
#                                  VIS_bool 50          0.380952  0.095238
#                 elemetns_all     HER_bool 50          0.833333  0.096225
#                                  OER_bool 50          0.888889  0.111111
#                                  VIS_bool 50          0.714286  0.082479
#                 mofkey           HER_bool 50          0.833333  0.000000
#                                  OER_bool 50          0.777778  0.222222
#                                  VIS_bool 50          0.761905  0.095238
#
#                                                           lr      test_size  \
#                                                         mean  sem      mean
# n_bins n_epochs representation   target   train_size
# 2      25       elements_linkers HER_bool 50          0.0003  0.0      12.0
#                                  OER_bool 50          0.0003  0.0       6.0
#                                  VIS_bool 50          0.0003  0.0      14.0
#                 elements_nodes   HER_bool 50          0.0003  0.0      12.0
#                                  OER_bool 50          0.0003  0.0       6.0
#                                  VIS_bool 50          0.0003  0.0      14.0
#                 elemetns_all     HER_bool 50          0.0003  0.0      12.0
#                                  OER_bool 50          0.0003  0.0       6.0
#                                  VIS_bool 50          0.0003  0.0      14.0
#                 mofkey           HER_bool 50          0.0003  0.0      12.0
#                                  OER_bool 50          0.0003  0.0       6.0
#                                  VIS_bool 50          0.0003  0.0      14.0
#
#
#                                                       sem
# n_bins n_epochs representation   target   train_size
# 2      25       elements_linkers HER_bool 50          0.0
#                                  OER_bool 50          0.0
#                                  VIS_bool 50          0.0
#                 elements_nodes   HER_bool 50          0.0
#                                  OER_bool 50          0.0
#                                  VIS_bool 50          0.0
#                 elemetns_all     HER_bool 50          0.0
#                                  OER_bool 50          0.0
#                                  VIS_bool 50          0.0
#                 mofkey           HER_bool 50          0.0
#                                  OER_bool 50          0.0
#                                  VIS_bool 50          0.0

# %%
def plot():
    fig, ax = plt.subplots(4,1, figsize=(ONE_COL_WIDTH_INCH, TWO_COL_GOLDEN_RATIO_HEIGHT_INCH),constrained_layout = True , sharex=True)
    try:
        folder_llma.plot_analysis(bins = 2, representation='elemetns_all', target = 'HER_bool', ax = ax, exclude = {'n_epochs': [5]})
        folder_gptj.plot_analysis(bins = 2, representation='elemetns_all', target = 'HER_bool', ax = ax, exclude = {'n_epochs': [5]})
        folder_mistral.plot_analysis(bins = 2, representation='elemetns_all', target = 'HER_bool', ax = ax, exclude = {'n_epochs': [5]})

        folder_mistral.add_zero_rule(ax = ax, color = 'slategray', exclude = {'train_size': [5]})
    except Exception as e:
        print('No data yet',e)
    #ax = add_traditional_ml(ax, file = './ml/ActivationEnergy_cycloadditions_traditional_ml.csv', target='E_bin')
    #ax = add_zero_rule(ax)

    import matplotx
    matplotx.line_labels(ax[0])

    ax[3].tick_params(axis='x', rotation=45)

    fig.savefig('photocatMOFs_LearningCurves_allModels.pdf')

plot()

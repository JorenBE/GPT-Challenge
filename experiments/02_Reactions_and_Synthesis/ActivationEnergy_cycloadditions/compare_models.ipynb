# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
import matplotlib.pyplot as plt
from datetime import datetime
import ast

from gptchem_llama.analyze import OutPickle, OutFolder, add_traditional_ml
import gptchem_llama.plotting

from gptchem_llama.plotting import *

FOLDER_LLAMA = 'LearningCurves_models/out_llama'
FOLDER_GPTJ = 'LearningCurves_models/out'
FOLDER_MISTRAL = 'LearningCurves_models/out_mistral'

# %%
print('Llama')
try:
    folder_llma = OutFolder(FOLDER_LLAMA)
    folder_llma_df = folder_llma.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_llma_df)
except:
    print('Data not present')
# Out:
# Llama
#                                                   accuracy            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.000000  0.000000
#                                       50          0.446667  0.035277
#                                       100         0.466667  0.013333
#                                       250         0.533333  0.006667
#                                       500         0.573333  0.013333
#        15       SMILES         E_bin  10          0.533333  0.037118
#                                       50          0.526667  0.035277
#                                       100         0.526667  0.017638
#                                       250         0.780000  0.050332
#                                       500         0.886667  0.033333
#        25       SMILES         E_bin  10          0.606667  0.035277
#                                       50          0.600000  0.050332
#                                       100         0.720000  0.050332
#                                       250         0.860000  0.011547
#                                       500         0.846667  0.024037
#
#                                                   f1_macro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.000000  0.000000
#                                       50          0.360663  0.016205
#                                       100         0.378321  0.025248
#                                       250         0.452691  0.018715
#                                       500         0.490332  0.025835
#        15       SMILES         E_bin  10          0.466956  0.086430
#                                       50          0.433114  0.056647
#                                       100         0.422702  0.029053
#                                       250         0.768831  0.058502
#                                       500         0.885253  0.034426
#        25       SMILES         E_bin  10          0.562936  0.074469
#                                       50          0.560071  0.065595
#                                       100         0.703848  0.060894
#                                       250         0.858492  0.011999
#                                       500         0.845157  0.024808
#
#                                                   f1_micro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.000000  0.000000
#                                       50          0.446667  0.035277
#                                       100         0.466667  0.013333
#                                       250         0.533333  0.006667
#                                       500         0.573333  0.013333
#        15       SMILES         E_bin  10          0.533333  0.037118
#                                       50          0.526667  0.035277
#                                       100         0.526667  0.017638
#                                       250         0.780000  0.050332
#                                       500         0.886667  0.033333
#        25       SMILES         E_bin  10          0.606667  0.035277
#                                       50          0.600000  0.050332
#                                       100         0.720000  0.050332
#                                       250         0.860000  0.011547
#                                       500         0.846667  0.024037
#
#                                                      kappa                lr  \
#                                                       mean       sem    mean
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.000000  0.000000  0.0003
#                                       50         -0.106667  0.070553  0.0003
#                                       100        -0.066667  0.026667  0.0003
#                                       250         0.066667  0.013333  0.0003
#                                       500         0.146667  0.026667  0.0003
#        15       SMILES         E_bin  10          0.080513  0.060598  0.0003
#                                       50          0.053333  0.070553  0.0003
#                                       100         0.053333  0.035277  0.0003
#                                       250         0.560000  0.100664  0.0003
#                                       500         0.773333  0.066667  0.0003
#        25       SMILES         E_bin  10          0.213333  0.070553  0.0003
#                                       50          0.200000  0.100664  0.0003
#                                       100         0.440000  0.100664  0.0003
#                                       250         0.720000  0.023094  0.0003
#                                       500         0.693333  0.048074  0.0003
#
#                                                       test_size
#                                                   sem      mean  sem
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       250         0.0      50.0  0.0
#                                       500         0.0      50.0  0.0
#        15       SMILES         E_bin  10          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       250         0.0      50.0  0.0
#                                       500         0.0      50.0  0.0
#        25       SMILES         E_bin  10          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       250         0.0      50.0  0.0
#                                       500         0.0      50.0  0.0

# %%
print('Mistral')
try:
    folder_mistral = OutFolder(FOLDER_MISTRAL)
    folder_mistral_df = folder_mistral.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_mistral_df)
except:
    print('Data not present')
# Out:
# Mistral
#                                                   accuracy            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         E_bin  10          0.560000  0.064291
#                                       50          0.733333  0.043716
#                                       100         0.713333  0.046667
#                                       250         0.880000  0.020000
#                                       300         0.800000       NaN
#                                       500         0.880000  0.060000
#
#                                                   f1_macro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         E_bin  10          0.496609  0.093811
#                                       50          0.726750  0.047960
#                                       100         0.704590  0.048693
#                                       250         0.879566  0.020072
#                                       300         0.798712       NaN
#                                       500         0.876878  0.062905
#
#                                                   f1_micro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         E_bin  10          0.560000  0.064291
#                                       50          0.733333  0.043716
#                                       100         0.713333  0.046667
#                                       250         0.880000  0.020000
#                                       300         0.800000       NaN
#                                       500         0.880000  0.060000
#
#                                                      kappa                lr  \
#                                                       mean       sem    mean
# n_bins n_epochs representation target train_size
# 2      25       SMILES         E_bin  10          0.120000  0.128582  0.0003
#                                       50          0.466667  0.087433  0.0003
#                                       100         0.426667  0.093333  0.0003
#                                       250         0.760000  0.040000  0.0003
#                                       300         0.600000       NaN  0.0003
#                                       500         0.760000  0.120000  0.0003
#
#                                                       test_size
#                                                   sem      mean  sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         E_bin  10          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       250         0.0      50.0  0.0
#                                       300         NaN      50.0  NaN
#                                       500         0.0      50.0  0.0

# %%
print('GPTJ')
try:
    folder_gptj = OutFolder(FOLDER_GPTJ)
    folder_gptj_df = folder_gptj.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_gptj_df)
except:
    print('Data not present')
# Out:
# GPTJ
#                                                   accuracy            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.000000  0.000000
#                                       50          0.553333  0.026667
#                                       100         0.640000  0.052915
#                                       250         0.753333  0.054569
#                                       500         0.873333  0.006667
#        15       SMILES         E_bin  10          0.593333  0.006667
#                                       50          0.680000  0.041633
#                                       100         0.793333  0.024037
#                                       250         0.846667  0.043716
#                                       500         0.900000  0.020000
#        25       SMILES         E_bin  10          0.493333  0.029059
#                                       50          0.733333  0.026667
#                                       100         0.786667  0.017638
#                                       250         0.833333  0.054569
#                                       500         0.940000  0.030551
#
#                                                   f1_macro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.000000  0.000000
#                                       50          0.450522  0.058594
#                                       100         0.628996  0.055138
#                                       250         0.750393  0.056015
#                                       500         0.873186  0.006621
#        15       SMILES         E_bin  10          0.566885  0.022051
#                                       50          0.678547  0.042452
#                                       100         0.793176  0.024134
#                                       250         0.846031  0.044154
#                                       500         0.899992  0.019992
#        25       SMILES         E_bin  10          0.457642  0.032190
#                                       50          0.732390  0.027226
#                                       100         0.786292  0.017536
#                                       250         0.832703  0.054717
#                                       500         0.939976  0.030542
#
#                                                   f1_micro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.000000  0.000000
#                                       50          0.553333  0.026667
#                                       100         0.640000  0.052915
#                                       250         0.753333  0.054569
#                                       500         0.873333  0.006667
#        15       SMILES         E_bin  10          0.593333  0.006667
#                                       50          0.680000  0.041633
#                                       100         0.793333  0.024037
#                                       250         0.846667  0.043716
#                                       500         0.900000  0.020000
#        25       SMILES         E_bin  10          0.493333  0.029059
#                                       50          0.733333  0.026667
#                                       100         0.786667  0.017638
#                                       250         0.833333  0.054569
#                                       500         0.940000  0.030551
#
#                                                      kappa                lr  \
#                                                       mean       sem    mean
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.000000  0.000000  0.0003
#                                       50          0.106667  0.053333  0.0003
#                                       100         0.280000  0.105830  0.0003
#                                       250         0.506667  0.109138  0.0003
#                                       500         0.746667  0.013333  0.0003
#        15       SMILES         E_bin  10          0.186667  0.013333  0.0003
#                                       50          0.360000  0.083267  0.0003
#                                       100         0.586667  0.048074  0.0003
#                                       250         0.693333  0.087433  0.0003
#                                       500         0.800000  0.040000  0.0003
#        25       SMILES         E_bin  10         -0.013333  0.058119  0.0003
#                                       50          0.466667  0.053333  0.0003
#                                       100         0.573333  0.035277  0.0003
#                                       250         0.666667  0.109138  0.0003
#                                       500         0.880000  0.061101  0.0003
#
#                                                       test_size
#                                                   sem      mean  sem
# n_bins n_epochs representation target train_size
# 2      5        SMILES         E_bin  10          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       250         0.0      50.0  0.0
#                                       500         0.0      50.0  0.0
#        15       SMILES         E_bin  10          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       250         0.0      50.0  0.0
#                                       500         0.0      50.0  0.0
#        25       SMILES         E_bin  10          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       250         0.0      50.0  0.0
#                                       500         0.0      50.0  0.0

# %%
def plot():
    fig, ax = plt.subplots(4,1, figsize=(ONE_COL_WIDTH_INCH, TWO_COL_GOLDEN_RATIO_HEIGHT_INCH),constrained_layout = True , sharex=True)
    try:
        folder_llma.plot_analysis(bins = 2, representation='SMILES', target = 'E_bin', ax = ax, exclude = {'n_epochs': [5,15]})
        folder_gptj.plot_analysis(bins = 2, representation='SMILES', target = 'E_bin', ax = ax, exclude = {'n_epochs': [5,15]})
        folder_mistral.plot_analysis(bins = 2, representation='SMILES', target = 'E_bin', ax = ax, exclude = {'n_epochs': [5,15]})

        folder_gptj.add_zero_rule(ax = ax, color = 'slategray', exclude = {'train_size': [5]})
    except Exception as e:
        print('No data yet' , e)
    ax = add_traditional_ml(ax, file = './ml/ActivationEnergy_cycloadditions_traditional_ml.csv', target='E_bin')
    #ax = add_zero_rule(ax)

    import matplotx
    matplotx.line_labels(ax[0])

    ax[3].tick_params(axis='x', rotation=45)

    fig.savefig('Click_LearningCurves_allModels.pdf')

plot()
# Out:
#                                           accuracy            f1_macro  \
#                                               mean       sem      mean
# modeltype              target train_size
# RandomForestClassifier E_bin  10          0.520000  0.040000  0.341168
#                               50          0.686667  0.035277  0.678221
#                               100         0.753333  0.006667  0.753042
#                               250         0.820000  0.023094  0.818191
#                               500         0.893333  0.035277  0.892840
#
#                                                     f1_micro            \
#                                                sem      mean       sem
# modeltype              target train_size
# RandomForestClassifier E_bin  10          0.017806  0.520000  0.040000
#                               50          0.032687  0.686667  0.035277
#                               100         0.006573  0.753333  0.006667
#                               250         0.021774  0.820000  0.023094
#                               500         0.035468  0.893333  0.035277
#
#                                              kappa
#                                               mean       sem
# modeltype              target train_size
# RandomForestClassifier E_bin  10          0.000000  0.000000
#                               50          0.373962  0.057938
#                               100         0.512992  0.015738
#                               250         0.638463  0.043428
#                               500         0.786406  0.070753
#                                  accuracy            f1_macro            \
#                                      mean       sem      mean       sem
# modeltype     target train_size
# XGBClassifier E_bin  10          0.520000  0.040000  0.341168  0.017806
#                      50          0.740000  0.041633  0.738612  0.041958
#                      100         0.813333  0.017638  0.812119  0.017517
#                      250         0.873333  0.024037  0.872118  0.023025
#                      500         0.913333  0.037118  0.912832  0.037378
#
#                                  f1_micro               kappa
#                                      mean       sem      mean       sem
# modeltype     target train_size
# XGBClassifier E_bin  10          0.520000  0.040000  0.000000  0.000000
#                      50          0.740000  0.041633  0.482598  0.080335
#                      100         0.813333  0.017638  0.627689  0.032581
#                      250         0.873333  0.024037  0.745885  0.045074
#                      500         0.913333  0.037118  0.826024  0.074664
# /home/jorenvanherck/.local/lib/python3.10/site-packages/matplotlib/ticker.py:2954: RuntimeWarning: invalid value encountered in log10
#   majorstep_no_exponent = 10 ** (np.log10(majorstep) % 1)
# /home/jorenvanherck/.local/lib/python3.10/site-packages/matplotlib/ticker.py:2954: RuntimeWarning: invalid value encountered in log10
#   majorstep_no_exponent = 10 ** (np.log10(majorstep) % 1)

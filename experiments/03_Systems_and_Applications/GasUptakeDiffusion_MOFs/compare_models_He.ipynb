# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
import matplotlib.pyplot as plt
from datetime import datetime
import ast

from gptchem_llama.analyze import OutPickle, OutFolder, add_traditional_ml
import gptchem_llama.plotting

from gptchem_llama.plotting import *

FOLDER_LLAMA = 'models_test/out_llama'
FOLDER_GPTJ = 'models_test/out_gptj'
FOLDER_MISTRAL = 'models_test/out_mistral'

# %%
print('Llama')
try:
    folder_llma = OutFolder(FOLDER_LLAMA)
    folder_llma_df = folder_llma.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_llma_df)
except:
    print('Data not present')
# Out:
# Llama
#                                                           accuracy            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.580000  0.060000
#                                               50          0.520000  0.030551
#                                               100         0.680000  0.020000
#                                               200         0.680000  0.050332
#                                               500         0.700000  0.052915
#                 mofkey         Diffusion_bool 500         0.506667  0.006667
#
#                                                           f1_macro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.503083  0.068668
#                                               50          0.512713  0.027762
#                                               100         0.677446  0.019255
#                                               200         0.679513  0.050577
#                                               500         0.697927  0.053911
#                 mofkey         Diffusion_bool 500         0.358479  0.012933
#
#                                                           f1_micro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.580000  0.060000
#                                               50          0.520000  0.030551
#                                               100         0.680000  0.020000
#                                               200         0.680000  0.050332
#                                               500         0.700000  0.052915
#                 mofkey         Diffusion_bool 500         0.506667  0.006667
#
#                                                              kappa            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.164706  0.122421
#                                               50          0.040000  0.061101
#                                               100         0.360000  0.040000
#                                               200         0.360000  0.100664
#                                               500         0.400000  0.105830
#                 mofkey         Diffusion_bool 500         0.013333  0.013333
#
#                                                               lr       \
#                                                             mean  sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.0003  0.0
#                                               50          0.0003  0.0
#                                               100         0.0003  0.0
#                                               200         0.0003  0.0
#                                               500         0.0003  0.0
#                 mofkey         Diffusion_bool 500         0.0003  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25              50.0  0.0
#                                               50              50.0  0.0
#                                               100             50.0  0.0
#                                               200             50.0  0.0
#                                               500             50.0  0.0
#                 mofkey         Diffusion_bool 500             50.0  0.0

# %%
print('Mistral')
try:
    folder_mistral = OutFolder(FOLDER_MISTRAL)
    folder_mistral_df = folder_mistral.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_mistral_df)
except:
    print('Data not present')
# Out:
# Mistral
#                                                           accuracy            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.580000  0.030551
#                                               50          0.620000  0.040000
#                                               100         0.660000  0.041633
#                                               200         0.686667  0.037118
#                                               500         0.726667  0.006667
#                 mofkey         Diffusion_bool 500         0.520000  0.034641
#
#                                                           f1_macro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.568655  0.025818
#                                               50          0.611995  0.040660
#                                               100         0.658828  0.041957
#                                               200         0.682551  0.038623
#                                               500         0.724428  0.006580
#                 mofkey         Diffusion_bool 500         0.423191  0.074555
#
#                                                           f1_micro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.580000  0.030551
#                                               50          0.620000  0.040000
#                                               100         0.660000  0.041633
#                                               200         0.686667  0.037118
#                                               500         0.726667  0.006667
#                 mofkey         Diffusion_bool 500         0.520000  0.034641
#
#                                                              kappa            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.160000  0.061101
#                                               50          0.240000  0.080000
#                                               100         0.320000  0.083267
#                                               200         0.373333  0.074237
#                                               500         0.453333  0.013333
#                 mofkey         Diffusion_bool 500         0.047059  0.063267
#
#                                                               lr       \
#                                                             mean  sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.0003  0.0
#                                               50          0.0003  0.0
#                                               100         0.0003  0.0
#                                               200         0.0003  0.0
#                                               500         0.0003  0.0
#                 mofkey         Diffusion_bool 500         0.0003  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25              50.0  0.0
#                                               50              50.0  0.0
#                                               100             50.0  0.0
#                                               200             50.0  0.0
#                                               500             50.0  0.0
#                 mofkey         Diffusion_bool 500             50.0  0.0

# %%
print('GPTJ')
try:
    folder_gptj = OutFolder(FOLDER_GPTJ)
    folder_gptj_df = folder_gptj.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_gptj_df)
except:
    print('Data not present')
# Out:
# GPTJ
#                                                           accuracy            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.466667  0.017638
#                                               50          0.613333  0.006667
#                                               100         0.626667  0.024037
#                                               200         0.640000  0.023094
#                                               500         0.720000  0.000000
#                 mofkey         Diffusion_bool 500         0.560000  0.011547
#
#                                                           f1_macro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.400299  0.048304
#                                               50          0.592322  0.011231
#                                               100         0.624362  0.024059
#                                               200         0.572970  0.087255
#                                               500         0.718337  0.001214
#                 mofkey         Diffusion_bool 500         0.558938  0.011586
#
#                                                           f1_micro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.466667  0.017638
#                                               50          0.613333  0.006667
#                                               100         0.626667  0.024037
#                                               200         0.640000  0.023094
#                                               500         0.720000  0.000000
#                 mofkey         Diffusion_bool 500         0.560000  0.011547
#
#                                                              kappa            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25         -0.059608  0.034643
#                                               50          0.226667  0.013333
#                                               100         0.253333  0.048074
#                                               200         0.285229  0.041742
#                                               500         0.440000  0.000000
#                 mofkey         Diffusion_bool 500         0.120000  0.023094
#
#                                                               lr       \
#                                                             mean  sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.0003  0.0
#                                               50          0.0003  0.0
#                                               100         0.0003  0.0
#                                               200         0.0003  0.0
#                                               500         0.0003  0.0
#                 mofkey         Diffusion_bool 500         0.0003  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25              50.0  0.0
#                                               50              50.0  0.0
#                                               100             50.0  0.0
#                                               200             50.0  0.0
#                                               500             50.0  0.0
#                 mofkey         Diffusion_bool 500             50.0  0.0

# %%
def plot():
    fig, ax = plt.subplots(4,1, figsize=(ONE_COL_WIDTH_INCH, TWO_COL_GOLDEN_RATIO_HEIGHT_INCH),constrained_layout = True , sharex=True)
    try:
        folder_llma.plot_analysis(bins = 2, representation='ABCD', target = 'Diffusion_bool', ax = ax, exclude = {'train_size': [5]})
        folder_gptj.plot_analysis(bins = 2, representation='ABCD', target = 'Diffusion_bool', ax = ax, exclude = {'train_size': [5]})
        folder_mistral.plot_analysis(bins = 2, representation='ABCD', target = 'Diffusion_bool', ax = ax, exclude = {'train_size': [5]})

        folder_mistral.add_zero_rule(ax = ax, color = 'slategray', exclude = {'train_size': [5]})
    except Exception as e:
        print('No data yet', e)
    ax = add_traditional_ml(ax, file = './ml/GasUptakeDiffusion_MOFS_He_traditional_ml.csv', target='Diffusion_bool')
    #ax = add_zero_rule(ax)

    import matplotx
    matplotx.line_labels(ax[0])

    ax[3].tick_params(axis='x', rotation=45)

    fig.savefig('HeDiffusion_LearningCurves_allModels.pdf')

plot()
# Out:
#                                                   accuracy            \
#                                                       mean       sem
# modeltype              target         train_size
# RandomForestClassifier Diffusion_bool 25          0.666667  0.017638
#                                       50          0.720000  0.030551
#                                       100         0.713333  0.063596
#                                       200         0.793333  0.024037
#                                       500         0.766667  0.046667
#
#                                                   f1_macro            \
#                                                       mean       sem
# modeltype              target         train_size
# RandomForestClassifier Diffusion_bool 25          0.661769  0.017304
#                                       50          0.711101  0.031762
#                                       100         0.704664  0.063531
#                                       200         0.786924  0.027043
#                                       500         0.764993  0.048046
#
#                                                   f1_micro            \
#                                                       mean       sem
# modeltype              target         train_size
# RandomForestClassifier Diffusion_bool 25          0.666667  0.017638
#                                       50          0.720000  0.030551
#                                       100         0.713333  0.063596
#                                       200         0.793333  0.024037
#                                       500         0.766667  0.046667
#
#                                                      kappa
#                                                       mean       sem
# modeltype              target         train_size
# RandomForestClassifier Diffusion_bool 25          0.334232  0.029208
#                                       50          0.423216  0.063788
#                                       100         0.412267  0.128188
#                                       200         0.575370  0.054429
#                                       500         0.532383  0.097030
#                                          accuracy            f1_macro  \
#                                              mean       sem      mean
# modeltype     target         train_size
# XGBClassifier Diffusion_bool 25          0.666667  0.006667  0.661698
#                              50          0.740000  0.060000  0.731624
#                              100         0.713333  0.033333  0.709622
#                              200         0.780000  0.034641  0.773211
#                              500         0.726667  0.035277  0.725458
#
#                                                    f1_micro            \
#                                               sem      mean       sem
# modeltype     target         train_size
# XGBClassifier Diffusion_bool 25          0.006882  0.666667  0.006667
#                              50          0.060679  0.740000  0.060000
#                              100         0.032999  0.713333  0.033333
#                              200         0.039350  0.780000  0.034641
#                              500         0.036331  0.726667  0.035277
#
#                                             kappa
#                                              mean       sem
# modeltype     target         train_size
# XGBClassifier Diffusion_bool 25          0.332723  0.009671
#                              50          0.464988  0.122017
#                              100         0.420001  0.065710
#                              200         0.547467  0.078576
#                              500         0.452426  0.072045
# /home/jorenvanherck/.local/lib/python3.10/site-packages/matplotlib/ticker.py:2954: RuntimeWarning: invalid value encountered in log10
#   majorstep_no_exponent = 10 ** (np.log10(majorstep) % 1)
# /home/jorenvanherck/.local/lib/python3.10/site-packages/matplotlib/ticker.py:2954: RuntimeWarning: invalid value encountered in log10
#   majorstep_no_exponent = 10 ** (np.log10(majorstep) % 1)

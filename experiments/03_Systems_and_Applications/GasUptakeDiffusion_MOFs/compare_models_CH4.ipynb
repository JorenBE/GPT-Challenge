# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
import matplotlib.pyplot as plt
from datetime import datetime
import ast

from gptchem_llama.analyze import OutPickle, OutFolder, add_traditional_ml
import gptchem_llama.plotting

from gptchem_llama.plotting import *

FOLDER_LLAMA = 'models_test/out_llama'
FOLDER_GPTJ = 'LearningCurve_models/out_gptj'
FOLDER_MISTRAL = 'LearningCurve_models/out_mistral'

# %%
print('Llama')
try:
    folder_llma = OutFolder(FOLDER_LLAMA)
    folder_llma_df = folder_llma.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_llma_df)
except:
    print('Data not present')
# Out:
# Llama
#                                                           accuracy            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.580000  0.060000
#                                               50          0.520000  0.030551
#                                               100         0.680000  0.020000
#                                               200         0.680000  0.050332
#                                               500         0.700000  0.052915
#                 mofkey         Diffusion_bool 500         0.506667  0.006667
#
#                                                           f1_macro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.503083  0.068668
#                                               50          0.512713  0.027762
#                                               100         0.677446  0.019255
#                                               200         0.679513  0.050577
#                                               500         0.697927  0.053911
#                 mofkey         Diffusion_bool 500         0.358479  0.012933
#
#                                                           f1_micro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.580000  0.060000
#                                               50          0.520000  0.030551
#                                               100         0.680000  0.020000
#                                               200         0.680000  0.050332
#                                               500         0.700000  0.052915
#                 mofkey         Diffusion_bool 500         0.506667  0.006667
#
#                                                              kappa            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.164706  0.122421
#                                               50          0.040000  0.061101
#                                               100         0.360000  0.040000
#                                               200         0.360000  0.100664
#                                               500         0.400000  0.105830
#                 mofkey         Diffusion_bool 500         0.013333  0.013333
#
#                                                               lr       \
#                                                             mean  sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25          0.0003  0.0
#                                               50          0.0003  0.0
#                                               100         0.0003  0.0
#                                               200         0.0003  0.0
#                                               500         0.0003  0.0
#                 mofkey         Diffusion_bool 500         0.0003  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      25       ABCD           Diffusion_bool 25              50.0  0.0
#                                               50              50.0  0.0
#                                               100             50.0  0.0
#                                               200             50.0  0.0
#                                               500             50.0  0.0
#                 mofkey         Diffusion_bool 500             50.0  0.0

# %%
print('Mistral')
try:
    folder_mistral = OutFolder(FOLDER_MISTRAL)
    folder_mistral_df = folder_mistral.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_mistral_df)
except:
    print('Data not present')
# Out:
# Mistral
# Data not present

# %%
print('GPTJ')
try:
    folder_gptj = OutFolder(FOLDER_GPTJ)
    folder_gptj_df = folder_gptj.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_gptj_df)
except:
    print('Data not present')
# Out:
# GPTJ
# Data not present

# %%
def plot():
    fig, ax = plt.subplots(4,1, figsize=(ONE_COL_WIDTH_INCH, TWO_COL_GOLDEN_RATIO_HEIGHT_INCH),constrained_layout = True , sharex=True)
    try:
        folder_llma.plot_analysis(bins = 2, representation='total_string', target = 'grain_size_bin', ax = ax, exclude = {'train_size': [5]})
        folder_gptj.plot_analysis(bins = 2, representation='total_string', target = 'grain_size_bin', ax = ax, exclude = {'train_size': [5]})
        folder_mistral.plot_analysis(bins = 2, representation='total_string', target = 'grain_size_bin', ax = ax, exclude = {'train_size': [5]})

        folder_mistral.add_zero_rule(ax = ax, color = 'slategray', exclude = {'train_size': [5]})
    except:
        print('No data yet')
    ax = add_traditional_ml(ax, file = './ml/GasUptakeDiffusion_MOFS_CH4_traditional_ml.csv', target='Diffusion_bool')
    #ax = add_zero_rule(ax)

    import matplotx
    matplotx.line_labels(ax[0])

    ax[3].tick_params(axis='x', rotation=45)

    fig.savefig('CH4Diffusion_LearningCurves_allModels.pdf')

plot()
# Out:
# No data yet
#                                                   accuracy            \
#                                                       mean       sem
# modeltype              target         train_size
# RandomForestClassifier Diffusion_bool 25          0.773333  0.026667
#                                       50          0.806667  0.006667
#                                       100         0.800000  0.023094
#                                       200         0.846667  0.029059
#                                       500         0.813333  0.043716
#
#                                                   f1_macro            \
#                                                       mean       sem
# modeltype              target         train_size
# RandomForestClassifier Diffusion_bool 25          0.766225  0.031673
#                                       50          0.799790  0.010131
#                                       100         0.798402  0.024107
#                                       200         0.845773  0.029333
#                                       500         0.812433  0.044013
#
#                                                   f1_micro            \
#                                                       mean       sem
# modeltype              target         train_size
# RandomForestClassifier Diffusion_bool 25          0.773333  0.026667
#                                       50          0.806667  0.006667
#                                       100         0.800000  0.023094
#                                       200         0.846667  0.029059
#                                       500         0.813333  0.043716
#
#                                                      kappa
#                                                       mean       sem
# modeltype              target         train_size
# RandomForestClassifier Diffusion_bool 25          0.539825  0.059218
#                                       50          0.604511  0.019481
#                                       100         0.600498  0.049314
#                                       200         0.692690  0.058636
#                                       500         0.625982  0.087401
#                                          accuracy            f1_macro  \
#                                              mean       sem      mean
# modeltype     target         train_size
# XGBClassifier Diffusion_bool 25          0.773333  0.026667  0.767129
#                              50          0.773333  0.006667  0.766713
#                              100         0.833333  0.006667  0.832384
#                              200         0.860000  0.020000  0.858757
#                              500         0.806667  0.037118  0.805822
#
#                                                    f1_micro            \
#                                               sem      mean       sem
# modeltype     target         train_size
# XGBClassifier Diffusion_bool 25          0.027288  0.773333  0.026667
#                              50          0.010741  0.773333  0.006667
#                              100         0.007107  0.833333  0.006667
#                              200         0.020444  0.860000  0.020000
#                              500         0.037475  0.806667  0.037118
#
#                                             kappa
#                                              mean       sem
# modeltype     target         train_size
# XGBClassifier Diffusion_bool 25          0.539736  0.057387
#                              50          0.541302  0.019025
#                              100         0.667864  0.015688
#                              200         0.718102  0.040956
#                              500         0.612862  0.074407

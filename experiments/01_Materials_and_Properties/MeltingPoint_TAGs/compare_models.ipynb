# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
import matplotlib.pyplot as plt
from datetime import datetime
import ast

from gptchem_llama.analyze import OutPickle, OutFolder, add_traditional_ml
import gptchem_llama.plotting

from gptchem_llama.plotting import *

FOLDER_LLAMA = 'LearningCurve_models/out_llama'
FOLDER_GPTJ = 'LearningCurve_models/out'
FOLDER_MISTRAL = 'LearningCurve_models/out_mistral'

# %%
folder_llma = OutFolder(FOLDER_LLAMA)
folder_llma_df = folder_llma.get_df(df_type= 'analysis')
print('Llama')
display(folder_llma_df)
# Out:
# Llama
#                                                   accuracy            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.626667  0.085114
#                                       25          0.786667  0.017638
#                                       50          0.913333  0.013333
#                                       100         0.913333  0.026667
#                                       150         0.920000  0.023094
#
#                                                   f1_macro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.616160  0.089649
#                                       25          0.783280  0.020257
#                                       50          0.913192  0.013393
#                                       100         0.913234  0.026645
#                                       150         0.920000  0.023094
#
#                                                   f1_micro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.626667  0.085114
#                                       25          0.786667  0.017638
#                                       50          0.913333  0.013333
#                                       100         0.913333  0.026667
#                                       150         0.920000  0.023094
#
#                                                      kappa                lr  \
#                                                       mean       sem    mean
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.253333  0.170229  0.0003
#                                       25          0.573333  0.035277  0.0003
#                                       50          0.826667  0.026667  0.0003
#                                       100         0.826667  0.053333  0.0003
#                                       150         0.840000  0.046188  0.0003
#
#                                                       test_size
#                                                   sem      mean  sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.0      50.0  0.0
#                                       25          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       150         0.0      50.0  0.0

# %%
folder_mistral = OutFolder(FOLDER_MISTRAL)
folder_mistral_df = folder_mistral.get_df(df_type= 'analysis')
print('Mistral')
display(folder_mistral_df)
# Out:
# Mistral
#                                                   accuracy            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.726667  0.081921
#                                       25          0.786667  0.048074
#                                       50          0.866667  0.013333
#                                       100         0.953333  0.017638
#                                       150         0.873333  0.037118
#
#                                                   f1_macro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.696924  0.098920
#                                       25          0.786002  0.048322
#                                       50          0.866453  0.013355
#                                       100         0.953309  0.017632
#                                       150         0.872719  0.037430
#
#                                                   f1_micro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.726667  0.081921
#                                       25          0.786667  0.048074
#                                       50          0.866667  0.013333
#                                       100         0.953333  0.017638
#                                       150         0.873333  0.037118
#
#                                                      kappa                lr  \
#                                                       mean       sem    mean
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.453333  0.163843  0.0003
#                                       25          0.573333  0.096148  0.0003
#                                       50          0.733333  0.026667  0.0003
#                                       100         0.906667  0.035277  0.0003
#                                       150         0.746667  0.074237  0.0003
#
#                                                       test_size
#                                                   sem      mean  sem
# n_bins n_epochs representation target train_size
# 2      25       SMILES         mp_bin 10          0.0      50.0  0.0
#                                       25          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       150         0.0      50.0  0.0

# %%
folder_gptj = OutFolder(FOLDER_GPTJ)
folder_gptj_df = folder_gptj.get_df(df_type= 'analysis')
print('GPTJ')
display(folder_gptj_df)
# Out:
# GPTJ
#                                                   accuracy            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       InChI          mp_bin 10          0.880000  0.046188
#                                       25          0.866667  0.017638
#                                       50          0.906667  0.024037
#                                       100         0.933333  0.033333
#                                       150         0.940000  0.000000
#                 SMILES         mp_bin 10          0.813333  0.048074
#                                       25          0.880000  0.011547
#                                       50          0.886667  0.013333
#                                       100         0.933333  0.017638
#                                       150         0.920000  0.020000
#                 iupac          mp_bin 10          0.606667  0.059255
#                                       25          0.846667  0.059255
#                                       50          0.866667  0.033333
#                                       100         0.953333  0.017638
#                                       150         0.946667  0.017638
#                 omega          mp_bin 10          0.740000  0.061101
#                                       25          0.740000  0.030551
#                                       50          0.786667  0.024037
#                                       100         0.846667  0.017638
#                                       150         0.926667  0.006667
#
#                                                   f1_macro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       InChI          mp_bin 10          0.876616  0.048582
#                                       25          0.864760  0.018431
#                                       50          0.906447  0.024183
#                                       100         0.932876  0.033562
#                                       150         0.939912  0.000064
#                 SMILES         mp_bin 10          0.805050  0.055708
#                                       25          0.878666  0.012077
#                                       50          0.886364  0.013435
#                                       100         0.933291  0.017633
#                                       150         0.919952  0.019992
#                 iupac          mp_bin 10          0.584373  0.057213
#                                       25          0.846106  0.059617
#                                       50          0.863648  0.035991
#                                       100         0.953331  0.017636
#                                       150         0.946484  0.017767
#                 omega          mp_bin 10          0.658232  0.122646
#                                       25          0.728317  0.037576
#                                       50          0.785078  0.024443
#                                       100         0.846299  0.017724
#                                       150         0.926423  0.006682
#
#                                                   f1_micro            \
#                                                       mean       sem
# n_bins n_epochs representation target train_size
# 2      25       InChI          mp_bin 10          0.880000  0.046188
#                                       25          0.866667  0.017638
#                                       50          0.906667  0.024037
#                                       100         0.933333  0.033333
#                                       150         0.940000  0.000000
#                 SMILES         mp_bin 10          0.813333  0.048074
#                                       25          0.880000  0.011547
#                                       50          0.886667  0.013333
#                                       100         0.933333  0.017638
#                                       150         0.920000  0.020000
#                 iupac          mp_bin 10          0.606667  0.059255
#                                       25          0.846667  0.059255
#                                       50          0.866667  0.033333
#                                       100         0.953333  0.017638
#                                       150         0.946667  0.017638
#                 omega          mp_bin 10          0.740000  0.061101
#                                       25          0.740000  0.030551
#                                       50          0.786667  0.024037
#                                       100         0.846667  0.017638
#                                       150         0.926667  0.006667
#
#                                                      kappa                lr  \
#                                                       mean       sem    mean
# n_bins n_epochs representation target train_size
# 2      25       InChI          mp_bin 10          0.760000  0.092376  0.0003
#                                       25          0.733333  0.035277  0.0003
#                                       50          0.813333  0.048074  0.0003
#                                       100         0.866667  0.066667  0.0003
#                                       150         0.880000  0.000000  0.0003
#                 SMILES         mp_bin 10          0.626667  0.096148  0.0003
#                                       25          0.760000  0.023094  0.0003
#                                       50          0.773333  0.026667  0.0003
#                                       100         0.866667  0.035277  0.0003
#                                       150         0.840000  0.040000  0.0003
#                 iupac          mp_bin 10          0.213333  0.118509  0.0003
#                                       25          0.693333  0.118509  0.0003
#                                       50          0.733333  0.066667  0.0003
#                                       100         0.906667  0.035277  0.0003
#                                       150         0.893333  0.035277  0.0003
#                 omega          mp_bin 10          0.484444  0.119340  0.0003
#                                       25          0.480000  0.061101  0.0003
#                                       50          0.573333  0.048074  0.0003
#                                       100         0.693333  0.035277  0.0003
#                                       150         0.853333  0.013333  0.0003
#
#                                                       test_size
#                                                   sem      mean  sem
# n_bins n_epochs representation target train_size
# 2      25       InChI          mp_bin 10          0.0      50.0  0.0
#                                       25          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       150         0.0      50.0  0.0
#                 SMILES         mp_bin 10          0.0      50.0  0.0
#                                       25          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       150         0.0      50.0  0.0
#                 iupac          mp_bin 10          0.0      50.0  0.0
#                                       25          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       150         0.0      50.0  0.0
#                 omega          mp_bin 10          0.0      50.0  0.0
#                                       25          0.0      50.0  0.0
#                                       50          0.0      50.0  0.0
#                                       100         0.0      50.0  0.0
#                                       150         0.0      50.0  0.0

# %%
fig, ax = plt.subplots(4,1, figsize=(ONE_COL_WIDTH_INCH, TWO_COL_GOLDEN_RATIO_HEIGHT_INCH),constrained_layout = True , sharex=True)

folder_llma.plot_analysis(bins = 2, representation='SMILES', target = 'mp_bin', ax = ax)
folder_gptj.plot_analysis(bins = 2, representation='SMILES', target = 'mp_bin', ax = ax)
folder_mistral.plot_analysis(bins = 2, representation='SMILES', target = 'mp_bin', ax = ax)

folder_gptj.add_zero_rule(ax = ax, color = 'slategray')

ax = add_traditional_ml(ax, file = './ml/fats_turino_traditional_ml.csv', target='mp_bin')
#ax = add_zero_rule(ax)

import matplotx
matplotx.line_labels(ax[0])

ax[3].tick_params(axis='x', rotation=45)

fig.savefig('MeltingPoint_TAG_LearningCurves_allModels.pdf')
# Out:
#                                           accuracy            f1_macro  \
#                                               mean       sem      mean
# modeltype              target train_size
# RandomForestClassifier mp_bin 25          0.780000  0.050332  0.772504
#                               50          0.793333  0.006667  0.791619
#                               100         0.846667  0.006667  0.840220
#                               150         0.866667  0.013333  0.863407
#
#                                                     f1_micro            \
#                                                sem      mean       sem
# modeltype              target train_size
# RandomForestClassifier mp_bin 25          0.053584  0.780000  0.050332
#                               50          0.006972  0.793333  0.006667
#                               100         0.011044  0.846667  0.006667
#                               150         0.016593  0.866667  0.013333
#
#                                              kappa
#                                               mean       sem
# modeltype              target train_size
# RandomForestClassifier mp_bin 25          0.554120  0.098526
#                               50          0.585190  0.015098
#                               100         0.682354  0.020579
#                               150         0.728077  0.033829
#                                  accuracy            f1_macro            \
#                                      mean       sem      mean       sem
# modeltype     target train_size
# XGBClassifier mp_bin 25          0.780000  0.060000  0.771583  0.061604
#                      50          0.813333  0.013333  0.812447  0.012608
#                      100         0.840000  0.023094  0.833422  0.024127
#                      150         0.873333  0.017638  0.872068  0.016878
#
#                                  f1_micro               kappa
#                                      mean       sem      mean       sem
# modeltype     target train_size
# XGBClassifier mp_bin 25          0.780000  0.060000  0.550956  0.115723
#                      50          0.813333  0.013333  0.627001  0.024217
#                      100         0.840000  0.023094  0.672219  0.045503
#                      150         0.873333  0.017638  0.745581  0.033407
# /home/jorenvanherck/.local/lib/python3.10/site-packages/matplotlib/ticker.py:2954: RuntimeWarning: invalid value encountered in log10
#   majorstep_no_exponent = 10 ** (np.log10(majorstep) % 1)
# /home/jorenvanherck/.local/lib/python3.10/site-packages/matplotlib/ticker.py:2954: RuntimeWarning: invalid value encountered in log10
#   majorstep_no_exponent = 10 ** (np.log10(majorstep) % 1)

# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
import matplotlib.pyplot as plt
from datetime import datetime
import ast

from gptchem_llama.analyze import OutPickle, OutFolder, add_traditional_ml
import gptchem_llama.plotting

from gptchem_llama.plotting import *

FOLDER_LLAMA = 'LearningCurves_models/out_llama'
FOLDER_GPTJ = 'LearningCurves_models/out'
FOLDER_MISTRAL = 'LearningCurves_models/out_mistral'

# %%
print('Llama')
try:
    folder_llma = OutFolder(FOLDER_LLAMA)
    folder_llma_df = folder_llma.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_llma_df)
except:
    print('Data not present')
# Out:
# Llama
#                                                     accuracy            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.813333  0.024037
#                                min_plus 75          0.640000  0.030551
#                                pdb_plus 75          0.853333  0.017638
#
#                                                     f1_macro            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.812943  0.024232
#                                min_plus 75          0.639449  0.031032
#                                pdb_plus 75          0.853098  0.017840
#
#                                                     f1_micro            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.813333  0.024037
#                                min_plus 75          0.640000  0.030551
#                                pdb_plus 75          0.853333  0.017638
#
#                                                        kappa            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.626667  0.048074
#                                min_plus 75          0.280000  0.061101
#                                pdb_plus 75          0.706667  0.035277
#
#                                                         lr      test_size
#                                                       mean  sem      mean  sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.0003  0.0      50.0  0.0
#                                min_plus 75          0.0003  0.0      50.0  0.0
#                                pdb_plus 75          0.0003  0.0      50.0  0.0

# %%
print('Mistral')
try:
    folder_mistral = OutFolder(FOLDER_MISTRAL)
    folder_mistral_df = folder_mistral.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_mistral_df)
except:
    print('Data not present')
# Out:
# Mistral
#                                                     accuracy            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.826667  0.046667
#                                min_plus 75          0.593333  0.033333
#                                pdb_plus 75          0.920000  0.020000
#
#                                                     f1_macro            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.826168  0.046556
#                                min_plus 75          0.593053  0.033406
#                                pdb_plus 75          0.919920  0.019960
#
#                                                     f1_micro            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.826667  0.046667
#                                min_plus 75          0.593333  0.033333
#                                pdb_plus 75          0.920000  0.020000
#
#                                                        kappa            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.653333  0.093333
#                                min_plus 75          0.186667  0.066667
#                                pdb_plus 75          0.840000  0.040000
#
#                                                         lr      test_size
#                                                       mean  sem      mean  sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.0003  0.0      50.0  0.0
#                                min_plus 75          0.0003  0.0      50.0  0.0
#                                pdb_plus 75          0.0003  0.0      50.0  0.0

# %%
print('GPTJ')
try:
    folder_gptj = OutFolder(FOLDER_GPTJ)
    folder_gptj_df = folder_gptj.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
    display(folder_gptj_df)
except:
    print('Data not present')
# Out:
# GPTJ
#                                                     accuracy            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.826667  0.035277
#                                min_plus 75          0.640000  0.023094
#                                pdb_plus 75          0.953333  0.006667
#                 first_20       min_pdb  75          0.740000  0.011547
#                                min_plus 75          0.620000  0.052915
#                                pdb_plus 75          0.786667  0.033333
#                 lenght         min_pdb  75          0.573333  0.076884
#                                min_plus 75          0.620000  0.023094
#                                pdb_plus 75          0.640000  0.011547
#                 shuffle_seq    min_pdb  75          0.753333  0.037118
#                                min_plus 75          0.640000  0.061101
#                                pdb_plus 75          0.860000  0.020000
#
#                                                     f1_macro            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.826087  0.035716
#                                min_plus 75          0.638970  0.023695
#                                pdb_plus 75          0.953283  0.006653
#                 first_20       min_pdb  75          0.738975  0.011704
#                                min_plus 75          0.616874  0.052852
#                                pdb_plus 75          0.784080  0.034100
#                 lenght         min_pdb  75          0.572074  0.076396
#                                min_plus 75          0.616917  0.023601
#                                pdb_plus 75          0.638483  0.012625
#                 shuffle_seq    min_pdb  75          0.750772  0.038048
#                                min_plus 75          0.638391  0.061032
#                                pdb_plus 75          0.859536  0.020054
#
#                                                     f1_micro            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.826667  0.035277
#                                min_plus 75          0.640000  0.023094
#                                pdb_plus 75          0.953333  0.006667
#                 first_20       min_pdb  75          0.740000  0.011547
#                                min_plus 75          0.620000  0.052915
#                                pdb_plus 75          0.786667  0.033333
#                 lenght         min_pdb  75          0.573333  0.076884
#                                min_plus 75          0.620000  0.023094
#                                pdb_plus 75          0.640000  0.011547
#                 shuffle_seq    min_pdb  75          0.753333  0.037118
#                                min_plus 75          0.640000  0.061101
#                                pdb_plus 75          0.860000  0.020000
#
#                                                        kappa            \
#                                                         mean       sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.653333  0.070553
#                                min_plus 75          0.280000  0.046188
#                                pdb_plus 75          0.906667  0.013333
#                 first_20       min_pdb  75          0.480000  0.023094
#                                min_plus 75          0.240000  0.105830
#                                pdb_plus 75          0.573333  0.066667
#                 lenght         min_pdb  75          0.146667  0.153768
#                                min_plus 75          0.240000  0.046188
#                                pdb_plus 75          0.280000  0.023094
#                 shuffle_seq    min_pdb  75          0.506667  0.074237
#                                min_plus 75          0.280000  0.122202
#                                pdb_plus 75          0.720000  0.040000
#
#                                                         lr      test_size
#                                                       mean  sem      mean  sem
# n_bins n_epochs representation target   train_size
# 2      25       Sequence       min_pdb  75          0.0003  0.0      50.0  0.0
#                                min_plus 75          0.0003  0.0      50.0  0.0
#                                pdb_plus 75          0.0003  0.0      50.0  0.0
#                 first_20       min_pdb  75          0.0003  0.0      50.0  0.0
#                                min_plus 75          0.0003  0.0      50.0  0.0
#                                pdb_plus 75          0.0003  0.0      50.0  0.0
#                 lenght         min_pdb  75          0.0003  0.0      50.0  0.0
#                                min_plus 75          0.0003  0.0      50.0  0.0
#                                pdb_plus 75          0.0003  0.0      50.0  0.0
#                 shuffle_seq    min_pdb  75          0.0003  0.0      50.0  0.0
#                                min_plus 75          0.0003  0.0      50.0  0.0
#                                pdb_plus 75          0.0003  0.0      50.0  0.0

# %%
def plot():
    fig, ax = plt.subplots(4,1, figsize=(ONE_COL_WIDTH_INCH, TWO_COL_GOLDEN_RATIO_HEIGHT_INCH),constrained_layout = True , sharex=True)
    try:
        folder_llma.plot_analysis(bins = 2, representation='Sequence', target = 'min_pdb', ax = ax, exclude = {'train_size': [5]})
        folder_gptj.plot_analysis(bins = 2, representation='Sequence', target = 'min_pdb', ax = ax, exclude = {'train_size': [5]})
        #folder_mistral.plot_analysis(bins = 2, representation='Sequence', target = 'min_pdb', ax = ax, exclude = {'train_size': [5]})

        folder_gptj.add_zero_rule(ax = ax, color = 'slategray', exclude = {'train_size': [5]})
    except:
        print('No data yet')
    #ax = add_traditional_ml(ax, file = './ml/ActivationEnergy_cycloadditions_traditional_ml.csv', target='E_bin')
    #ax = add_zero_rule(ax)

    import matplotx
    matplotx.line_labels(ax[0])

    ax[3].tick_params(axis='x', rotation=45)

    fig.savefig('Click_LearningCurves_allModels.pdf')

plot()

# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
import matplotlib.pyplot as plt
from datetime import datetime
import ast

from gptchem_llama.analyze import OutPickle, OutFolder, add_traditional_ml
import gptchem_llama.plotting

from gptchem_llama.plotting import *

FOLDER_LLAMA = 'LearningCurve_models/out_llama'
FOLDER_GPTJ = 'LearningCurve_models/out_gptj'
FOLDER_MISTRAL = 'LearningCurve_models/out_mistral'

# %%
folder_llma = OutFolder(FOLDER_LLAMA)
folder_llma_df = folder_llma.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
print('Llama')
display(folder_llma_df.round(2))
# Out:
# Llama
#                                                          accuracy        \
#                                                              mean   sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10             0.86  0.02
#                                               25             0.93  0.02
#                                               30             0.89  0.03
#
#                                                          f1_macro        \
#                                                              mean   sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10             0.86  0.02
#                                               25             0.93  0.02
#                                               30             0.89  0.03
#
#                                                          f1_micro       kappa  \
#                                                              mean   sem  mean
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10             0.86  0.02  0.72
#                                               25             0.93  0.02  0.87
#                                               30             0.89  0.03  0.79
#
#                                                                  lr       \
#                                                            sem mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10          0.05  0.0  0.0
#                                               25          0.04  0.0  0.0
#                                               30          0.06  0.0  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10              50.0  0.0
#                                               25              50.0  0.0
#                                               30              50.0  0.0

# %%
folder_mistral = OutFolder(FOLDER_MISTRAL)
folder_mistral_df = folder_mistral.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
print('Mistral')
display(folder_mistral_df.round(2))
# Out:
# Mistral
#                                                          accuracy        \
#                                                              mean   sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10             0.85  0.10
#                                               25             0.94  0.02
#                                               30             0.94  0.01
#
#                                                          f1_macro        \
#                                                              mean   sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10             0.83  0.11
#                                               25             0.94  0.02
#                                               30             0.94  0.01
#
#                                                          f1_micro       kappa  \
#                                                              mean   sem  mean
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10             0.85  0.10  0.69
#                                               25             0.94  0.02  0.88
#                                               30             0.94  0.01  0.88
#
#                                                                  lr       \
#                                                            sem mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10          0.19  0.0  0.0
#                                               25          0.04  0.0  0.0
#                                               30          0.02  0.0  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10              50.0  0.0
#                                               25              50.0  0.0
#                                               30              50.0  0.0

# %%
folder_gptj = OutFolder(FOLDER_GPTJ)
folder_gptj_df = folder_gptj.get_df(df_type= 'analysis', exclude = {'train_size': [5]})
print('GPTJ')
display(folder_gptj_df.round(2))
# Out:
# GPTJ
#                                                          accuracy        \
#                                                              mean   sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10             0.81  0.07
#                                               25             0.83  0.04
#                                               30             0.85  0.03
#
#                                                          f1_macro        \
#                                                              mean   sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10             0.80  0.08
#                                               25             0.82  0.04
#                                               30             0.85  0.03
#
#                                                          f1_micro       kappa  \
#                                                              mean   sem  mean
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10             0.81  0.07  0.63
#                                               25             0.83  0.04  0.65
#                                               30             0.85  0.03  0.71
#
#                                                                  lr       \
#                                                            sem mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10          0.13  0.0  0.0
#                                               25          0.07  0.0  0.0
#                                               30          0.07  0.0  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 10              50.0  0.0
#                                               25              50.0  0.0
#                                               30              50.0  0.0

# %%
fig, ax = plt.subplots(4,1, figsize=(ONE_COL_WIDTH_INCH, TWO_COL_GOLDEN_RATIO_HEIGHT_INCH),constrained_layout = True , sharex=True)

folder_llma.plot_analysis(bins = 2, representation='total_string', target = 'grain_size_bin', ax = ax, exclude = {'train_size': [5]})
folder_gptj.plot_analysis(bins = 2, representation='total_string', target = 'grain_size_bin', ax = ax, exclude = {'train_size': [5]})
folder_mistral.plot_analysis(bins = 2, representation='total_string', target = 'grain_size_bin', ax = ax, exclude = {'train_size': [5]})

folder_mistral.add_zero_rule(ax = ax, color = 'slategray', exclude = {'train_size': [5]})

ax = add_traditional_ml(ax, file = './ml/Prop_MgAlloys_traditional_ml.csv', target='grain_size_bin')
#ax = add_zero_rule(ax)

import matplotx
matplotx.line_labels(ax[0])

ax[3].tick_params(axis='x', rotation=45)

fig.savefig('MgAlloys_LearningCurves_allModels.pdf')
# Out:
#                                                          accuracy            \
#                                                              mean       sem
# modeltype              target                train_size
# RandomForestClassifier grain_size_bin        10          0.926667  0.006667
#                                              25          0.933333  0.006667
#                                              30          0.953333  0.017638
#                        second_phase_bin_1.14 10          0.600000  0.150111
#                                              25          0.820000  0.030551
#                                              30          0.833333  0.024037
#
#                                                          f1_macro            \
#                                                              mean       sem
# modeltype              target                train_size
# RandomForestClassifier grain_size_bin        10          0.926033  0.006878
#                                              25          0.931216  0.006680
#                                              30          0.952321  0.017855
#                        second_phase_bin_1.14 10          0.506754  0.196461
#                                              25          0.813860  0.034793
#                                              30          0.830274  0.025800
#
#                                                          f1_micro            \
#                                                              mean       sem
# modeltype              target                train_size
# RandomForestClassifier grain_size_bin        10          0.926667  0.006667
#                                              25          0.933333  0.006667
#                                              30          0.953333  0.017638
#                        second_phase_bin_1.14 10          0.600000  0.150111
#                                              25          0.820000  0.030551
#                                              30          0.833333  0.024037
#
#                                                             kappa
#                                                              mean       sem
# modeltype              target                train_size
# RandomForestClassifier grain_size_bin        10          0.852903  0.013554
#                                              25          0.863096  0.013157
#                                              30          0.905042  0.035394
#                        second_phase_bin_1.14 10          0.267091  0.267091
#                                              25          0.637410  0.063753
#                                              30          0.667684  0.048585
#                                                 accuracy            f1_macro  \
#                                                     mean       sem      mean
# modeltype     target                train_size
# XGBClassifier grain_size_bin        10          0.546667  0.078599  0.445286
#                                     25          0.933333  0.006667  0.931216
#                                     30          0.946667  0.013333  0.945527
#               second_phase_bin_1.14 10          0.460000  0.011547  0.314983
#                                     25          0.800000  0.020000  0.796093
#                                     30          0.853333  0.024037  0.852628
#
#                                                           f1_micro            \
#                                                      sem      mean       sem
# modeltype     target                train_size
# XGBClassifier grain_size_bin        10          0.126097  0.546667  0.078599
#                                     25          0.006680  0.933333  0.006667
#                                     30          0.013351  0.946667  0.013333
#               second_phase_bin_1.14 10          0.005418  0.460000  0.011547
#                                     25          0.021205  0.800000  0.020000
#                                     30          0.024471  0.853333  0.024037
#
#                                                    kappa
#                                                     mean       sem
# modeltype     target                train_size
# XGBClassifier grain_size_bin        10          0.132045  0.132045
#                                     25          0.863096  0.013157
#                                     30          0.891493  0.026399
#               second_phase_bin_1.14 10          0.000000  0.000000
#                                     25          0.598541  0.042053
#                                     30          0.706879  0.048280

# %%
from fastcore.xtras import load_pickle
import pandas as pd 
import os 
from glob import glob
import matplotlib.pyplot as plt
from datetime import datetime

from gptchem_llama.analyze import OutPickle, OutFolder
import gptchem_llama.plotting

from gptchem_llama.plotting import *

FOLDER_LLAMA = 'out_llama'
FOLDER_GPTJ = 'out_gptj'
FOLDER_MISTRAL = 'out_mistral'

FOLDER_GPTJ_OLD = 'out'
# Out:
# Matplotlib parameters: activated

# %%
folder_llma = OutFolder(FOLDER_LLAMA)
folder_llma_df = folder_llma.get_df(df_type= 'analysis')
display(folder_llma_df)
# Out:
#                                                           accuracy            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.740000  0.110151
#                                               10          0.860000  0.023094
#                                               25          0.933333  0.017638
#                                               30          0.893333  0.029059
#
#                                                           f1_macro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.717813  0.128277
#                                               10          0.858768  0.024128
#                                               25          0.933226  0.017621
#                                               30          0.892797  0.029303
#
#                                                           f1_micro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.740000  0.110151
#                                               10          0.860000  0.023094
#                                               25          0.933333  0.017638
#                                               30          0.893333  0.029059
#
#                                                              kappa            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.480000  0.220303
#                                               10          0.720000  0.046188
#                                               25          0.866667  0.035277
#                                               30          0.786667  0.058119
#
#                                                               lr       \
#                                                             mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.0003  0.0
#                                               10          0.0003  0.0
#                                               25          0.0003  0.0
#                                               30          0.0003  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5               50.0  0.0
#                                               10              50.0  0.0
#                                               25              50.0  0.0
#                                               30              50.0  0.0

# %%
folder_mistral = OutFolder(FOLDER_MISTRAL)
folder_mistral_df = folder_mistral.get_df(df_type= 'analysis')
display(folder_mistral_df)
# Out:
#                                                           accuracy            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.886667  0.033333
#                                               10          0.846667  0.096148
#                                               25          0.940000  0.020000
#                                               30          0.940000  0.011547
#
#                                                           f1_macro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.885253  0.034426
#                                               10          0.831730  0.110547
#                                               25          0.939944  0.019992
#                                               30          0.939928  0.011566
#
#                                                           f1_micro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.886667  0.033333
#                                               10          0.846667  0.096148
#                                               25          0.940000  0.020000
#                                               30          0.940000  0.011547
#
#                                                              kappa            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.773333  0.066667
#                                               10          0.693333  0.192296
#                                               25          0.880000  0.040000
#                                               30          0.880000  0.023094
#
#                                                               lr       \
#                                                             mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.0003  0.0
#                                               10          0.0003  0.0
#                                               25          0.0003  0.0
#                                               30          0.0003  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5               50.0  0.0
#                                               10              50.0  0.0
#                                               25              50.0  0.0
#                                               30              50.0  0.0

# %%
folder_gptj = OutFolder(FOLDER_GPTJ)
folder_gptj_df = folder_gptj.get_df(df_type= 'analysis')
display(folder_gptj_df)
# Out:
#                                                           accuracy            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.833333  0.059255
#                                               10          0.813333  0.066667
#                                               25          0.826667  0.037118
#                                               30          0.853333  0.033333
#
#                                                           f1_macro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.826986  0.064492
#                                               10          0.800323  0.078415
#                                               25          0.821065  0.039994
#                                               30          0.850763  0.034361
#
#                                                           f1_micro            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.833333  0.059255
#                                               10          0.813333  0.066667
#                                               25          0.826667  0.037118
#                                               30          0.853333  0.033333
#
#                                                              kappa            \
#                                                               mean       sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.666667  0.118509
#                                               10          0.626667  0.133333
#                                               25          0.653333  0.074237
#                                               30          0.706667  0.066667
#
#                                                               lr       \
#                                                             mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5           0.0003  0.0
#                                               10          0.0003  0.0
#                                               25          0.0003  0.0
#                                               30          0.0003  0.0
#
#                                                          test_size
#                                                               mean  sem
# n_bins n_epochs representation target         train_size
# 2      100      total_string   grain_size_bin 5               50.0  0.0
#                                               10              50.0  0.0
#                                               25              50.0  0.0
#                                               30              50.0  0.0

# %%
fig, ax = plt.subplots(4,1, figsize=(ONE_COL_WIDTH_INCH, TWO_COL_GOLDEN_RATIO_HEIGHT_INCH),constrained_layout = True , sharex=True)

folder_llma.plot_analysis(bins = 2, representation='total_string', target = 'grain_size_bin', ax = ax)
folder_gptj.plot_analysis(bins = 2, representation='total_string', target = 'grain_size_bin', ax = ax)
folder_mistral.plot_analysis(bins = 2, representation='total_string', target = 'grain_size_bin', ax = ax)
